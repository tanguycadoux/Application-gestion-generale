# %% [markdown]
# # Cheatsheet

# %% [markdown]
# ## Venv activation
# `.venv\Scripts\Activate.ps1`

# %% [markdown]
# ## Serveur
# Migration : `py manage.py migrate`
#
# Lancement : `py manage.py runserver`
